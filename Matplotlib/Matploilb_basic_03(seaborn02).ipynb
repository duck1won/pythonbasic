# %%
# %cd fonts
# Out:
# [WinError 2] 지정된 파일을 찾을 수 없습니다: 'fonts'
# C:\python\Matplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# 시스템 폰트 경로 리스트
font_list = mpl.font_manager.findSystemFonts()
print(font_list)
# 폰트 설정하기
prop = mpl.font_manager.FontProperties(fname='원하는 폰트 경로')
plt.rcParams['font.family'] = prop.get_family()

# Add every font at the specified location
font_dir = ['./fonts']
for font in mpl.font_manager.findSystemFonts(fontpaths=font_dir):
 print(mpl.font_manager.FontProperties(fname=font).get_name())
 mpl.font_manager.fontManager.addfont(font)
# Out:
# ['C:\\Windows\\Fonts\\PERTIBD.TTF', 'C:\\Windows\\Fonts\\MSUIGHUR.TTF', 'C:\\Windows\\Fonts\\BRUSHSCI.TTF', 'C:\\Windows\\Fonts\\SIMYOU.TTF', 'C:\\Windows\\Fonts\\gadugi.ttf', 'C:\\Windows\\Fonts\\FRAHV.TTF', 'C:\\Windows\\Fonts\\STHUPO.TTF', 'C:\\Windows\\Fonts\\ariblk.ttf', 'C:\\Windows\\Fonts\\BOOKOS.TTF', 'C:\\Windows\\Fonts\\seguisym.ttf', 'C:\\Windows\\Fonts\\impact.ttf', 'C:\\Windows\\Fonts\\trebuc.ttf', 'C:\\Windows\\Fonts\\consolab.ttf', 'C:\\Windows\\Fonts\\cambriab.ttf', 'C:\\Windows\\Fonts\\calibrii.ttf', 'C:\\Windows\\Fonts\\FELIXTI.TTF', 'C:\\Windows\\Fonts\\MTEXTRA.TTF', 'C:\\Windows\\Fonts\\LBRITED.TTF', 'C:\\Windows\\Fonts\\SCHLBKB.TTF', 'C:\\Windows\\Fonts\\Candaraz.ttf', 'C:\\Windows\\Fonts\\HMKMMAG.TTF', 'C:\\Windows\\Fonts\\ROCCB___.TTF', 'C:\\Windows\\Fonts\\LeelUIsl.ttf', 'C:\\Windows\\Fonts\\ebrima.ttf', 'C:\\Windows\\Fonts\\couri.ttf', 'C:\\Windows\\Fonts\\ARIALNI.TTF', 'C:\\Windows\\Fonts\\POORICH.TTF', 'C:\\Windows\\Fonts\\HMKMRHD.TTF', 'C:\\Windows\\Fonts\
# ...

# %%
# Set font family globally
mpl.rcParams['font.family'] = 'Noto Sans KR'
print(mpl.rcParams['font.family'])
# Out:
# ['Noto Sans KR']

# %%
# %matplotlib inline

# %%
mpl.rc("axes", unicode_minus=False)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# %cd ../datas
# Out:
# C:\python\datas

# %%
survey_raw_df = pd.read_csv("survey_results_public.csv",index_col="ResponseId")

# %%
survey_raw_df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 73264                          I am a developer by profession
# 73265                          I am a developer by profession
# 73266       I am not primarily a developer, but I write co...
# 73267                          I am a developer by profession
# 73268       I used to be a developer by profession, but no...
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# ...

# %%
schema_raw = pd.read_csv("survey_results_schema.csv",index_col="qname")["question"]

# %%
schema_raw
# Out:
# qname
# S0             <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo                                       Browser Meta Info
# S1             <span style="font-size:22px; font-family: aria...
# MainBranch     Which of the following options best describes ...
# Employment     Which of the following best describes your cur...
#                                      ...
# Frequency_2    Interacting with people outside of your immedi...
# Frequency_3    Encountering knowledge silos (where one indivi...
# TrueFalse_1    Are you involved in supporting new hires durin...
# TrueFalse_2    Do you use learning resources provided by your...
# TrueFalse_3    Does your employer give you time to learn new ...
# Name: question, Length: 79, dtype: object

# %%
survey_raw_df.columns
# Out:
# Index(['MainBranch', 'Employment', 'RemoteWork', 'CodingActivities', 'EdLevel',
#        'LearnCode', 'LearnCodeOnline', 'LearnCodeCoursesCert', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'PurchaseInfluence', 'BuyNewTool',
#        'Country', 'Currency', 'CompTotal', 'CompFreq',
#        'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith',
#        'OpSysProfessional use', 'OpSysPersonal use', 'VersionControlSystem',
#        'VCInteraction', 'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
schema_raw.index
# Out:
# Index(['S0', 'MetaInfo', 'S1', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'S2', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'S3', 'Language', 'Database', 'Platform',
#        'Webframe', 'MiscTech', 'ToolsTech', 'NEWCollabTools', 'OpSys',
#        'VersionControlSystem', 'VCInteraction', 'VCHosting',
#        'OfficeStackAsync', 'OfficeStackSync', 'Blockchain', 'S4', 'NEWSOSites',
#        'SOVisitFreq', 'SOAccount', 'SOPartFreq', 'SOComm', 'S5', 'Age',
#        'Gender', 'Trans', 'Sexuality', 'Ethnicity', 'Accessibility',
#        'MentalHealth', 'S6', 'TBranch', 'ICorPM', 'WorkExp', 'Knowledge',
#        'Frequency', 'TimeSearching', 'TimeAnswering', 'Onboarding',
#        'ProfessionalTech', 'SOTeamsUsage', 'TrueFalse', 'S7', 'SurveyLength',
# ...

# %%
#schema_raw indx = qname, values = question
#CompTotal이라 하는 column의 질문 내용을 확인합니다.
schema_raw["CompTotal"]
# Out:
# 'What is your current total compensation (salary, bonuses, and perks, before taxes and deductions)? Please enter a whole number in the box below, without any punctuation.  If you are paid hourly, please estimate an equivalent weekly, monthly, or yearly salary. If you prefer not to answer, please leave the box empty.'

# %%
schema_raw["CompFreq"]
# Out:
# 'Is that compensation weekly, monthly, or yearly?'

# %%
survey_raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73268 entries, 1 to 73268
# Data columns (total 78 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   MainBranch                      73268 non-null  object
#  1   Employment                      71709 non-null  object
#  2   RemoteWork                      58958 non-null  object
#  3   CodingActivities                58899 non-null  object
#  4   EdLevel                         71571 non-null  object
#  5   LearnCode                       71580 non-null  object
#  6   LearnCodeOnline                 50685 non-null  object
#  7   LearnCodeCoursesCert            29389 non-null  object
#  8   YearsCode                       71331 non-null  object
#  9   YearsCodePro                    51833 non-null  object
#  10  DevType                         61302 non-null  object
#  11  OrgSize                         51039 non-null  object
# ...

# %%
#columns의 개수가 많을 때 한번에 볼 수 있는 컬럼의 크기를 변화시켜줌.
pd.set_option("display.max_columns",78)
#rows에 대해 한번에 출력할 수 있는 크기를 조절함.
pd.set_option("display.max_rows",78)

# %%
survey_raw_df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 73264                          I am a developer by profession
# 73265                          I am a developer by profession
# 73266       I am not primarily a developer, but I write co...
# 73267                          I am a developer by profession
# 73268       I used to be a developer by profession, but no...
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# ...

# %%
selected_columns=[
#인구 통계
"Country",
"Age",
"Gender",
"EdLevel",
#프로그래밍 경험
'YearsCode',
'YearsCodePro',
'LanguageHaveWorkedWith',
'LanguageWantToWorkWith',
'LearnCodeCoursesCert',
'ProfessionalTech',
'SOAccount',
#고용 관련 정보
'Employment',
'DevType',
'WorkExp'
]

# %%
survey_df = survey_raw_df[selected_columns].copy()
survey_df
# Out:
#                                                       Country  \
# ResponseId
# 1                                                         NaN
# 2                                                      Canada
# 3           United Kingdom of Great Britain and Northern I...
# 4                                                      Israel
# 5                                    United States of America
# ...                                                       ...
# 73264                                                 Nigeria
# 73265                                United States of America
# 73266                                United States of America
# 73267       United Kingdom of Great Britain and Northern I...
# 73268                                                  Canada
#
#                         Age Gender  \
# ResponseId
# 1                       NaN    NaN
# 2                       NaN    NaN
# 3           25-34 years old    Man
# 4           35-44 years old    Man
# ...

# %%
survey_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73268 entries, 1 to 73268
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 71771 non-null  object
#  1   Age                     70946 non-null  object
#  2   Gender                  70853 non-null  object
#  3   EdLevel                 71571 non-null  object
#  4   YearsCode               71331 non-null  object
#  5   YearsCodePro            51833 non-null  object
#  6   LanguageHaveWorkedWith  70975 non-null  object
#  7   LanguageWantToWorkWith  67027 non-null  object
#  8   LearnCodeCoursesCert    29389 non-null  object
#  9   ProfessionalTech        34906 non-null  object
#  10  SOAccount               71572 non-null  object
#  11  Employment              71709 non-null  object
#  12  DevType                 61302 non-null  object
#  13  WorkExp                 36769 non-null  float64
# ...

# %%
print(schema_raw["YearsCode"])
# Out:
# Including any education, how many years have you been coding in total?

# %%
survey_df["YearsCode"].value_counts()
# Out:
# 10                    5217
# 5                     5193
# 6                     4651
# 4                     4480
# 7                     4237
# 8                     4227
# 3                     4122
# 2                     3351
# 12                    2995
# 15                    2962
# 20                    2659
# 9                     2581
# 11                    1819
# 14                    1811
# 13                    1624
# 25                    1582
# 1                     1566
# Less than 1 year      1413
# 16                    1406
# 30                    1330
# 22                    1176
# 18                    1150
# 17                    1080
# 40                     777
# 24                     752
# 35                     742
# 23                     644
# 19                     563
# 26                     489
# 27                     485
# 21                     483
# 28                     425
# 32                     371
# 38                     288
# ...

# %%
def count_nan(series):
    return series.isnull().sum()

# %%
count_nan(survey_df["YearsCode"])
# Out:
# 1937

# %%
survey_df["YearsCode"].replace(["Less than 1 year","More than 50 years"],[0,51],inplace=True)
survey_df["YearsCode"] = survey_df["YearsCode"].astype('float')
survey_df.dtypes
# Out:
# Country                    object
# Age                        object
# Gender                     object
# EdLevel                    object
# YearsCode                 float64
# YearsCodePro               object
# LanguageHaveWorkedWith     object
# LanguageWantToWorkWith     object
# LearnCodeCoursesCert       object
# ProfessionalTech           object
# SOAccount                  object
# Employment                 object
# DevType                    object
# WorkExp                   float64
# dtype: object

# %%
print(schema_raw["YearsCodePro"])
# Out:
# NOT including education, how many years have you coded professionally (as a part of your work)?

# %%
count_nan(survey_df["YearsCodePro"])
# Out:
# 21435

# %%
survey_df["YearsCodePro"].value_counts()
# Out:
# 3                     4261
# 5                     4057
# 2                     3945
# 4                     3884
# 10                    3333
# 6                     3184
# 7                     2760
# 8                     2646
# 1                     2644
# Less than 1 year      1972
# 15                    1822
# 12                    1711
# 9                     1583
# 20                    1472
# 11                    1369
# 14                    1048
# 22                     933
# 16                     921
# 13                     914
# 25                     877
# 18                     787
# 17                     723
# 30                     568
# 23                     463
# 24                     454
# 21                     429
# 19                     380
# 26                     320
# 27                     286
# 35                     266
# 28                     254
# 32                     223
# 40                     175
# 29                     126
# ...

# %%
survey_df["YearsCodePro"].replace(["Less than 1 year","More than 50 years"],[0,51],inplace=True)
survey_df["YearsCodePro"] = survey_df["YearsCodePro"].astype('float')
survey_df.dtypes
# Out:
# Country                    object
# Age                        object
# Gender                     object
# EdLevel                    object
# YearsCode                 float64
# YearsCodePro              float64
# LanguageHaveWorkedWith     object
# LanguageWantToWorkWith     object
# LearnCodeCoursesCert       object
# ProfessionalTech           object
# SOAccount                  object
# Employment                 object
# DevType                    object
# WorkExp                   float64
# dtype: object

# %%
survey_df.describe()
# Out:
#           YearsCode  YearsCodePro       WorkExp
# count  71331.000000  51833.000000  36769.000000
# mean      12.251307      9.910270     10.242378
# std        9.952419      8.712048      8.706850
# min        0.000000      0.000000      0.000000
# 25%        5.000000      4.000000      4.000000
# 50%        9.000000      7.000000      8.000000
# 75%       16.000000     14.000000     15.000000
# max       51.000000     51.000000     50.000000

# %%
survey_df2 = survey_raw_df[selected_columns].copy()
survey_df2['YearsCode'] = pd.to_numeric(survey_df2.YearsCode, errors = 'coerce')
survey_df2['YearsCodePro'] = pd.to_numeric(survey_df2.YearsCodePro, errors = 'coerce')

# %%
schema_raw["Gender"]
# Out:
# 'Which of the following describe you, if any? Please check all that apply.'

# %%
survey_df["Gender"].value_counts()
# Out:
# Man                                                                                   64607
# Woman                                                                                  3399
# Prefer not to say                                                                      1172
# Non-binary, genderqueer, or gender non-conforming                                       704
# Or, in your own words:                                                                  279
# Man;Non-binary, genderqueer, or gender non-conforming                                   235
# Man;Or, in your own words:                                                              171
# Woman;Non-binary, genderqueer, or gender non-conforming                                 160
# Man;Woman;Non-binary, genderqueer, or gender non-conforming                              31
# Man;Woman                                                                                24
# ...

# %%
survey_df.where(~(survey_df["Gender"].str.contains(";",na=False)),np.nan,inplace=True)

# %%
survey_df["Gender"].value_counts()
# Out:
# Man                                                  64607
# Woman                                                 3399
# Prefer not to say                                     1172
# Non-binary, genderqueer, or gender non-conforming      704
# Or, in your own words:                                 279
# Name: Gender, dtype: int64

# %%
# %matplotlib inline
sns.set_style("darkgrid")
mpl.rcParams['font.size'] = 14
mpl.rcParams['figure.figsize'] = (9,5)
mpl.rcParams['figure.facecolor'] = '#000000'

# %%
mpl.rcParams['axes.facecolor'] = 'white'

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
#use() 메서드에 'default' 값을 넣어주면 원래의 style로 되돌아 옴.
plt.style.use("default")

# %%
plt.plot(range(10))
plt.show()

# %%
import matplotlib.font_manager as font_manager
import matplotlib as mpl
# Add every font at the specified location
font_dir = ['C:/python/fonts']
for font in font_manager.findSystemFonts(fontpaths=font_dir):
    print(mpl.font_manager.FontProperties(fname=font).get_name())
    font_manager.fontManager.addfont(font)
# Out:
# Noto Sans KR
# NanumMyeongjoOTF
# NanumMyeongjo
# NanumBarunGothic
# NanumBarunGothic
# Noto Sans KR
# NanumBarunGothic
# NanumBarunGothicOTF
# NanumMyeongjo
# NanumBarunpen
# NanumBarunGothic
# Noto Sans KR
# Noto Sans KR
# NanumBarunpenOTF
# NanumBarunGothic
# NanumBarunGothicOTF
# NanumMyeongjoOTF
# Noto Sans KR
# NanumBarunGothicOTF
# NanumMyeongjoOTF
# NanumBarunpen
# Noto Sans KR
# NanumBarunGothicOTF
# NanumBarunpenOTF
# NanumMyeongjo

# %%
# Set font family globally
mpl.rcParams['font.family'] = 'Noto Sans KR'
print(mpl.rcParams['font.family'])
# Out:
# ['Noto Sans KR']

# %%
survey_df["Country"].nunique()
# Out:
# 180

# %%
survey_df["Country"].value_counts().nlargest(15)
# Out:
# United States of America                                13321
# India                                                    6618
# Germany                                                  5342
# United Kingdom of Great Britain and Northern Ireland     4132
# Canada                                                   2459
# France                                                   2306
# Brazil                                                   2088
# Poland                                                   1719
# Netherlands                                              1539
# Spain                                                    1511
# Italy                                                    1504
# Australia                                                1449
# Russian Federation                                       1215
# Turkey                                                   1014
# Sweden                                                   1008
# Name: Country, dtype: int64

# %%
data = survey_df["Country"].value_counts().head(15)
data.index
data.values
# Out:
# array([13321,  6618,  5342,  4132,  2459,  2306,  2088,  1719,  1539,
#         1511,  1504,  1449,  1215,  1014,  1008], dtype=int64)

# %%
plt.xticks(rotation=90)
plt.title("응답자의 지역")
plt.ylabel("응답자의 수")
sns.barplot(x=data.index,y= data.values)

plt.show()

# %%
schema_raw["Age"]
# Out:
# 'What is your age?'

# %%
count_nan(survey_df['Age'])
# Out:
# 3011

# %%
survey_df['Age'].unique()
# Out:
# array([nan, '25-34 years old', '35-44 years old', 'Under 18 years old',
#        '18-24 years old', '45-54 years old', '55-64 years old',
#        '65 years or older', 'Prefer not to say'], dtype=object)

# %%
survey_df['Age'].nunique()
# Out:
# 8

# %%
age_counts = survey_df['Age'].value_counts()

# %%
age_counts.unique()
# Out:
# array([27878, 16455, 13866,  5250,  3775,  1974,   547,   512],
#       dtype=int64)

# %%
age_counts.nunique()
# Out:
# 8

# %%
age_counts_sort = age_counts.sort_index()
age_counts_sort
# Out:
# 18-24 years old       16455
# 25-34 years old       27878
# 35-44 years old       13866
# 45-54 years old        5250
# 55-64 years old        1974
# 65 years or older       547
# Prefer not to say       512
# Under 18 years old     3775
# Name: Age, dtype: int64

# %%
age_counts_index=['Under 18 years old',
'18-24 years old', 
'25-34 years old',      
'35-44 years old',     
'45-54 years old',       
'55-64 years old',     
'65 years or older',
'Prefer not to say',      
]
plt.xticks(rotation=90)
plt.title("what is your age?")
plt.ylabel("응답자의 수")
sns.barplot(x = age_counts_sort.index, y = age_counts_sort.values , order = age_counts_index)
# Out:
# <AxesSubplot:title={'center':'what is your age?'}, ylabel='응답자의 수'>

# %%
plt.figure(figsize=(12,6))
plt.title(schema_raw["Age"])
plt.xticks(rotation=90)
sns.countplot(data=survey_df, x="Age", order=age_counts_index)
plt.xlabel('나이')
plt.ylabel('응답자의 수')
plt.show()

# %%
schema_raw.Gender
# Out:
# 'Which of the following describe you, if any? Please check all that apply.'

# %%
gender_counts = survey_df['Gender'].value_counts(True)
gender_counts
# Out:
# Man                                                  0.920839
# Woman                                                0.048446
# Prefer not to say                                    0.016704
# Non-binary, genderqueer, or gender non-conforming    0.010034
# Or, in your own words:                               0.003977
# Name: Gender, dtype: float64

# %%
labels = ['Man','Woman','Prefer not to say','Non-binary, genderqueer, or gender non-conforming','Or, in your own words:']
sizes = gender_counts.values
colors = ['blue','lightcoral','green','red','white']
explode = (0,0,0,0,0)
plt.title(schema_raw.Gender)
plt.pie(sizes,explode=explode,labels=labels,colors=colors,
       autopct='%1.1f%%',shadow=False,startangle=180)
plt.axis("equal")
plt.show()

# %%
# labeldistance: label의 pie 차트 중심으로부터의 거리
# pctdistance: 값의 pie 차트 중심으로부터의 거리
# rotatelabels: True일 때 label을 회전시켜서 출력합니다.
plt.title(schema_raw.Gender)
plt.pie(gender_counts.values,labels=gender_counts.index,autopct='%1.1f%%',
        startangle=180,labeldistance=1.5,pctdistance=1.2,rotatelabels=True)
plt.show()

# %%
schema_raw["EdLevel"]
# Out:
# 'Which of the following best describes the highest level of formal education that you’ve completed? *'

# %%
survey_df["EdLevel"].value_counts()
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          30050
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       15394
# Some college/university study without earning a degree                                 9194
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     7769
# Associate degree (A.A., A.S., etc.)                                                    2221
# Other doctoral degree (Ph.D., Ed.D., etc.)                                             2152
# Primary/elementary school                                                              1767
# Something else                                                                         1222
# Professional degree (JD, MD, etc.)                                                     1110
# Name: EdLevel, dtype: int64

# %%
plt.title(schema_raw["EdLevel"])
sns.countplot(data=survey_df, y="EdLevel")
plt.xticks(rotation=45)
plt.ylabel(None)
plt.show()
#order=age_counts_index

# %%
EdLevel_x = survey_df['EdLevel'].value_counts(True) * 100
EdLevel_x
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          42.396196
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       21.718704
# Some college/university study without earning a degree                                12.971402
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)    10.960933
# Associate degree (A.A., A.S., etc.)                                                    3.133509
# Other doctoral degree (Ph.D., Ed.D., etc.)                                             3.036160
# Primary/elementary school                                                              2.492981
# Something else                                                                         1.724065
# Professional degree (JD, MD, etc.)                                                     1.566049
# Name: EdLevel, dtype: float64

# %%
plt.title(schema_raw["EdLevel"])
sns.barplot(x=survey_df['EdLevel'].value_counts(True).values * 100, y= survey_df['EdLevel'].value_counts().index )
plt.ylabel(None)
plt.xlabel("Percentage")
plt.show()

# %%
schema_raw["Employment"]
# Out:
# 'Which of the following best describes your current employment status?'

# %%
survey_df["Employment"].value_counts()
# Out:
# Employed, full-time                                                                                               42644
# Student, full-time                                                                                                 6663
# Independent contractor, freelancer, or self-employed                                                               4941
# Employed, full-time;Independent contractor, freelancer, or self-employed                                           3456
# Not employed, but looking for work                                                                                 1810
#                                                                                                                   ...
# Student, part-time;Independent contractor, freelancer, or self-employed;Retired                                       1
# Employed, full-time;Student, full-time;Student, part-time;Independent contractor, freelancer, or self-employed        1
# ...

# %%
survey_df["Employment"].value_counts().head()
# Out:
# Employed, full-time                                                         42644
# Student, full-time                                                           6663
# Independent contractor, freelancer, or self-employed                         4941
# Employed, full-time;Independent contractor, freelancer, or self-employed     3456
# Not employed, but looking for work                                           1810
# Name: Employment, dtype: int64

# %%
plt.xlabel("Percentage")
plt.title(schema_raw["Employment"])
sns.barplot(x=survey_df["Employment"].value_counts(True).head(15).values * 100, y=survey_df["Employment"].value_counts(True).head(15).index)
plt.show()

# %%
schema_raw.DevType
# Out:
# 'Which of the following describes your current job? Please select all that apply.'

# %%
survey_df.DevType.count()
# Out:
# 60761

# %%
survey_df.DevType.value_counts()
# Out:
# Developer, full-stack                                                                                                                                                                                                                                                                                                                                                                                                                  7091
# Developer, back-end                                                                                                                                                                                                                                                                                                                                                                                                                    5274
# ...

# %%
def split_multicolumn(series):
    result_df = series.to_frame()
    options=[]
    for idx, value in series[series.notnull()].items():
        for option in value.split(';'):
            if option not in result_df.columns:
                options.append(option)
                result_df[option] = False
            result_df.at[idx,option] = True
            
    return result_df[options]
            


split_multicolumn(survey_df.DevType)
# Out:
#             Data scientist or machine learning specialist  \
# ResponseId
# 1                                                   False
# 2                                                   False
# 3                                                    True
# 4                                                   False
# 5                                                   False
# ...                                                   ...
# 73264                                               False
# 73265                                                True
# 73266                                               False
# 73267                                               False
# 73268                                               False
#
#             Developer, front-end  Engineer, data  Engineer, site reliability  \
# ResponseId
# 1                          False           False                       False
# 2                          False           False                       False
# ...

# %%
def split_multicolumn(series): 
    result_df = series.to_frame()
    options=[]
    for idx, value in series[series.notnull()].items():
        for option in value.split(';'):
            if option not in result_df.columns:
                options.append(option)
                result_df[option] = False
            result_df.at[idx,option] = True
    return result_df[options]

split_multicolumn(survey_df['DevType'])
# Out:
#             Data scientist or machine learning specialist  \
# ResponseId
# 1                                                   False
# 2                                                   False
# 3                                                    True
# 4                                                   False
# 5                                                   False
# ...                                                   ...
# 73264                                               False
# 73265                                                True
# 73266                                               False
# 73267                                               False
# 73268                                               False
#
#             Developer, front-end  Engineer, data  Engineer, site reliability  \
# ResponseId
# 1                          False           False                       False
# 2                          False           False                       False
# ...

# %%
data1 = split_multicolumn(survey_df['DevType'])
data3 = data1.sum().sort_values(ascending=False)
data3
# Out:
# Developer, full-stack                            28433
# Developer, back-end                              26369
# Developer, front-end                             15739
# Developer, desktop or enterprise applications     9451
# Developer, mobile                                 7566
# DevOps specialist                                 6093
# Student                                           5503
# Cloud infrastructure engineer                     5215
# Database administrator                            4872
# System administrator                              4828
# Developer, embedded applications or devices       3871
# Project manager                                   3844
# Designer                                          3712
# Engineer, data                                    3558
# Engineering manager                               3534
# Data scientist or machine learning specialist     3377
# Data or business analyst                          3166
# ...

# %%
devtype_percentage = (100/(data3.sum() / data3)).sort_values(ascending=False)

# %%
devtype_percentage
# Out:
# Developer, full-stack                            17.462842
# Developer, back-end                              16.195185
# Developer, front-end                              9.666503
# Developer, desktop or enterprise applications     5.804569
# Developer, mobile                                 4.646849
# DevOps specialist                                 3.742169
# Student                                           3.379806
# Cloud infrastructure engineer                     3.202923
# Database administrator                            2.992261
# System administrator                              2.965238
# Developer, embedded applications or devices       2.377472
# Project manager                                   2.360889
# Designer                                          2.279818
# Engineer, data                                    2.185235
# Engineering manager                               2.170495
# Data scientist or machine learning specialist     2.074070
# ...

# %%
plt.figure(figsize=(12,12))
plt.title(schema_raw["DevType"])
plt.xlabel("Percentage")
plt.ylabel(None)
sns.barplot(x = devtype_percentage, y = devtype_percentage.index)
plt.show()

# %%
survey_df['LanguageHaveWorkedWith']
data4 = split_multicolumn(survey_df['LanguageHaveWorkedWith'])
data5 = data4.sum().sort_values(ascending=False)
Languages_percentage = (100/(data5.sum() / data5)).sort_values(ascending=False)

plt.figure(figsize=(12,12))
plt.title("Languages used in the past year")
plt.xlabel("Percentage")
plt.ylabel(None)
sns.barplot(x=Languages_percentage,y=Languages_percentage.index)
plt.show()

# %%
South_Korea = survey_df[survey_df["Country"]=="South Korea"]
South_Korea['LanguageHaveWorkedWith']
data6 = split_multicolumn(South_Korea['LanguageHaveWorkedWith'])
data7 = data6.sum().sort_values(ascending=False)
South_Korea_percentage = (100/(data7.sum() / data7)).sort_values(ascending=False)

plt.figure(figsize=(12,12))
plt.title("Languages used in the past year in South Korea")
plt.xlabel("Percentage")
plt.ylabel(None)
sns.barplot(x=South_Korea_percentage,y=South_Korea_percentage.index)
plt.show()

# %%
Data_scientist= survey_df[data1['Data scientist or machine learning specialist']]
data8 = split_multicolumn(Data_scientist['LanguageHaveWorkedWith'])
data9 = data8.sum().sort_values(ascending=False)
Data_scientist_percentage = (100/(data9.sum() / data9)).sort_values(ascending=False)

plt.figure(figsize=(12,12))
plt.title("Languages used by Data Scientists or Machine Learning Folks")
plt.xlabel("Percentage")
plt.ylabel(None)
sns.barplot(x=Data_scientist_percentage,y=Data_scientist_percentage.index)
plt.show()

# %%
survey_df["LanguageWantToWorkWith"]

data10 = split_multicolumn(survey_df['LanguageWantToWorkWith'])
data11 = data10.sum().sort_values(ascending=False)
LanguageWantToWorkWith_percentage = (100/(data11.sum() / data11)).sort_values(ascending=False)

plt.figure(figsize=(12,12))
plt.title("Languages Interested to work with in coming years")
plt.xlabel("Percentage")
plt.ylabel(None)
sns.barplot(x=South_Korea_percentage,y=South_Korea_percentage.index)
plt.show()

# %%
survey_raw_df["DatabaseHaveWorkedWith"]

data12 = split_multicolumn(survey_raw_df['DatabaseHaveWorkedWith'])
data13 = data12.sum().sort_values(ascending=False)
DatabaseHaveWorkedWith_percentage = (100/(data13.sum() / data13)).sort_values(ascending=False)

plt.figure(figsize=(12,12))
plt.title("Database worked with")
plt.xlabel("count")
plt.ylabel(None)
sns.barplot(x=DatabaseHaveWorkedWith_percentage,y=DatabaseHaveWorkedWith_percentage.index)
plt.show()

# %%
import folium

# %%
latitude, longitude = (37.497159,126.927651)

# %%
m = folium.Map(location=[latitude,longitude],
              zoom_start=17,
              width=750,
              height=500
              )
popup_tag = """<div style='width:65px'>
    <a href="https://playdata.io">
        플레이데이터
    </a>
</div>
"""
folium.Marker([latitude,longitude],
             popup=popup_tag,
             tooltip="플레이데이터").add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import requests
import json

url = "https://raw.githubusercontent.com/johan/world.geo.json/master/countries.geo.json"
response = requests.get(url)
data_json = response.json()
countries_name = [feature['properties']['name'] for feature in data_json["features"]]

# %%
import pandas as pd

# %%
survey_raw_df = pd.read_csv("survey_results_public.csv",index_col="ResponseId")

# %%
country_counts = survey_raw_df.Country.value_counts()
country_counts_df = pd.DataFrame({'Country':country_counts.index,
                                 'Count':country_counts.values})
country_counts_df
# Out:
#                                                Country  Count
# 0                             United States of America  13543
# 1                                                India   6639
# 2                                              Germany   5395
# 3    United Kingdom of Great Britain and Northern I...   4190
# 4                                               Canada   2490
# ..                                                 ...    ...
# 175                                             Monaco      1
# 176                                           Djibouti      1
# 177                                         Seychelles      1
# 178                                    Solomon Islands      1
# 179                              Saint Kitts and Nevis      1
#
# [180 rows x 2 columns]

# %%
country_counts_df.at[12,'Country']
# Out:
# 'Russian Federation'

# %%
country_counts_df.at[12,'Country'] = "Russia"
country_counts_df.at[12,'Country']
# Out:
# 'Russia'

# %%
m = folium.Map(location=[30,0], zoom_start=2)
folium.Choropleth(
    geo_data=url,
    data=country_counts_df,
    columns=['Country', 'Count'],
    key_on='feature.properties.name',
    threshold_scale=[1,30,100,300,1_000,3_000,10_000,14_000],
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Respondents',
).add_to(m)
folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m.save("Country.html")

# %%
pip install wordcloud
# Out:
# Note: you may need to restart the kernel to use updated packages.Defaulting to user installation because normal site-packages is not writeable
# ...
#      -------------------------------------- 153.1/153.1 kB 9.5 MB/s eta 0:00:00
# ...
#   WARNING: The script wordcloud_cli.exe is installed in 'C:\Users\user\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
from wordcloud import WordCloud

# %%
survey_df.DevType
# Out:
# ResponseId
# 1                                                      NaN
# 2                                                      NaN
# 3        Data scientist or machine learning specialist;...
# 4                                    Developer, full-stack
# 5        Developer, front-end;Developer, full-stack;Dev...
#                                ...
# 73264                                  Developer, back-end
# 73265        Data scientist or machine learning specialist
# 73266    Developer, full-stack;Developer, desktop or en...
# 73267    Developer, front-end;Developer, desktop or ent...
# 73268    Developer, front-end;Engineer, data;Engineer, ...
# Name: DevType, Length: 73268, dtype: object

# %%
temp_words = survey_df.DevType.dropna()
temp_words
# Out:
# ResponseId
# 3        Data scientist or machine learning specialist;...
# 4                                    Developer, full-stack
# 5        Developer, front-end;Developer, full-stack;Dev...
# 8                            Developer, full-stack;Student
# 9                                      Developer, back-end
#                                ...
# 73264                                  Developer, back-end
# 73265        Data scientist or machine learning specialist
# 73266    Developer, full-stack;Developer, desktop or en...
# 73267    Developer, front-end;Developer, desktop or ent...
# 73268    Developer, front-end;Engineer, data;Engineer, ...
# Name: DevType, Length: 60761, dtype: object

# %%
words = ' '.join(temp_words)

# %%
wc = WordCloud(collocation_threshold=int(1e6),
               width=800, height=400,
               background_color='lightgrey').generate(words)

plt.axis('off')
plt.grid(False)
plt.imshow(wc)
plt.show()

# %%
wc.to_file("DevType.png")
